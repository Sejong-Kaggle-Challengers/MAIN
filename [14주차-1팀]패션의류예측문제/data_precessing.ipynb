# %%
# !pip install kaggle
from google.colab import files
files.upload()
# Out:
# ...
#      <input type="file" id="files-78642200-b60a-4487-afcd-e6d530ec06fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-78642200-b60a-4487-afcd-e6d530ec06fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"rheehyun","key":"9131c659702d5cbfc63306c6c7313d68"}'}

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# Permission Warning 이 일어나지 않도록 
# !chmod 600 ~/.kaggle/kaggle.json
# 본인이 참가한 모든 대회 보기 
# !kaggle competitions list
# Out:
# ...
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# contradictory-my-dear-watson                   2030-07-01 23:59:00  Getting Started     Prizes         97           False
# gan-getting-started                            2030-07-01 23:59:00  Getting Started     Prizes        206           False
# tpu-getting-started                            2030-06-03 23:59:00  Getting Started  Knowledge        470           False
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       3226           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      25957           False
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       6547           False
# ...

# %%
# !kaggle competitions download -c sejong-ai-challenge-p1
# Out:
# ...
#  26% 5.00M/19.0M [00:00<00:02, 5.94MB/s]
# 100% 19.0M/19.0M [00:00<00:00, 20.6MB/s]
# ...
# 100% 4.74M/4.74M [00:00<00:00, 36.5MB/s]
#
# ...
#   0% 0.00/72.8k [00:00<?, ?B/s]
# 100% 72.8k/72.8k [00:00<00:00, 63.1MB/s]

# %%
# !ls
# Out:
# kaggle.json  sample_data  sample_submission.csv  test.csv.zip  train.csv.zip

# %%
# !unzip test.csv.zip
# !unzip train.csv.zip
# Out:
# Archive:  test.csv.zip
#   inflating: test.csv
# Archive:  train.csv.zip
#   inflating: train.csv

# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv("/content/test.csv")
train = pd.read_csv("/content/train.csv")
submit = pd.read_csv("/content/sample_submission.csv")

# %%
train
# Out:
#           id  pixel1  pixel2  pixel3  ...  pixel782  pixel783  pixel784    label
# 0          0       0       0       0  ...         0         0         0  missing
# 1          1       0       0       0  ...         0         0         0        9
# 2          2       0       0       0  ...         0         0         0        6
# 3          3       0       0       0  ...         0         0         0      NAN
# 4          4       0       0       0  ...         0         0         0        3
# ...      ...     ...     ...     ...  ...       ...       ...       ...      ...
# 33835  59990       0       0       0  ...         0         0         0        0
# 33836  59991       0       0       0  ...         0         0         0        5
# 33837  59992       0       0       0  ...         0         0         0        5
# 33838  59993       0       0       0  ...         0         0         0  missing
# 33839  59999       0       0       0  ...         0         0         0        7
#
# ...

# %%
test
# Out:
#          id  pixel1  pixel2  pixel3  ...  pixel781  pixel782  pixel783  pixel784
# 0        11       0       0       0  ...         0         0         0         0
# 1        15       0       0       0  ...         0         0         0         0
# 2        17       0       0       0  ...         0         0         0         0
# 3        21       0       0       0  ...         0         0         0         0
# 4        22       0       0       0  ...         0         0         0         0
# ...     ...     ...     ...     ...  ...       ...       ...       ...       ...
# 8455  59970       0       0       0  ...         0         0         0         0
# 8456  59971       0       0       0  ...         0         0         0         0
# 8457  59982       0       0       0  ...        73         0         0         0
# 8458  59986       0       0       0  ...       124        27         0         0
# 8459  59996       0       0       0  ...         0         0         0         0
#
# ...

# %%
# train.keys()[-1] # 'label'
train['label']
# Out:
# 0        missing
# 1              9
# 2              6
# 3            NAN
# 4              3
#           ...
# 33835          0
# 33836          5
# 33837          5
# 33838    missing
# 33839          7
# Name: label, Length: 33840, dtype: object

# %%
train[train['label'].apply(lambda x: x.isnumeric() == False)]['label'].describe()
# Out:
# count        4887
# unique          2
# top       missing
# freq         4800
# Name: label, dtype: object

# %%
# train[train['label'].apply(lambda x: x.isnumeric() == False)]['label'].unique()
train['label'].unique()
# Out:
# array(['missing', '9', '6', 'NAN', '3', '4', '5', '8', '7', '1', '0'],
#       dtype=object)

# %%
train['label'].value_counts() # normalize=True
# missing -> label: 2, NAN: 0??? 이미지 확인후 결정 ㄱㄱ!
# Out:
# 5          4800
# missing    4800
# 1          4800
# 6          4800
# 7          4800
# 4          4800
# 0          4713
# NAN          87
# 3            80
# 8            80
# 9            80
# Name: label, dtype: int64

# %%
# https://www.geeksforgeeks.org/working-with-missing-data-in-pandas/
print(train.isnull().sum().sum())
print(train.isna().sum().sum())
# Out:
# 0
# 0

# %%
# train.describe()
# Out:
#                  id        pixel1  ...      pixel783      pixel784
# count  33840.000000  33840.000000  ...  33840.000000  33840.000000
# mean   29738.625827      0.000946  ...      0.575650      0.036436
# std    17443.784502      0.089320  ...      7.488179      1.351274
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%    14646.250000      0.000000  ...      0.000000      0.000000
# 50%    29738.500000      0.000000  ...      0.000000      0.000000
# 75%    44834.000000      0.000000  ...      0.000000      0.000000
# max    59999.000000     14.000000  ...    255.000000    142.000000
#
# [8 rows x 785 columns]
